# %% [markdown]
# # What is Pandas?
#
# * Pandas is a Python library used for working with data sets.
#
# * It has functions for analyzing, cleaning, exploring, and manipulating data.
# * Pandas allows us to analyze big data and make conclusions based on statistical theories.

# %% [markdown]
# Pandas gives you answers about the data. Like:
#
# *    Is there a correlation between two or more columns?
# *    What is average value?
# *   Max value?
# *    Min value?

# %%
import pandas as pd

# %% [markdown]
# ### A Pandas Series is like a column in a table.
#
# ### It is a one-dimensional array holding data of any type.

# %%
#series
x = (1, 9, 12)

myseries = pd.Series(x)

print(myseries)
# print(myseries[0])
myseries.shape
# Out:
# 0     1
# 1     9
# 2    12
# dtype: int64
# (3,)

# %%
myseries = pd.Series(x, index = ["x", "y", "z"])

print(myseries)
# Out:
# x     1
# y     9
# z    12
# dtype: int64

# %%
data = {"val1": 420, "val2": 380, "val3": 390}

myvar = pd.Series(data)
myvar.nbytes
# Out:
# 24

# %% [markdown]
# ## DataFrames
#
# Data sets in Pandas are usually multi-dimensional tables, called DataFrames.
#
# Series is like a column, a DataFrame is the whole table.

# %%
data = {
  "val1": [420, 380, 390],
  "val2": [50, 40, 45]
}

df = pd.DataFrame(data)
df
# Out:
#    val1  val2
# 0   420    50
# 1   380    40
# 2   390    45

# %%
# print(df.loc[1])
print(df.loc[[0, 1]])
df.loc[[0,1]]
# Out:
#    val1  val2
# 0   420    50
# 1   380    40
#    val1  val2
# 0   420    50
# 1   380    40

# %%
df = pd.DataFrame(data, index = ["x", "y", "z"])

df["val3"] = [89,90,100]
df
# df.iloc[2]
# print("The sum of column = ",df["val1"].sum())
# Out:
#    val1  val2  val3
# x   420    50    89
# y   380    40    90
# z   390    45   100

# %%
df = pd.read_csv('tested.csv')
# print(df.to_string())

# %%
print(df.to_string())
# Out:
#      PassengerId  Survived  Pclass                                                             Name     Sex    Age  SibSp  Parch              Ticket      Fare            Cabin Embarked
# 0            892         0       3                                                 Kelly, Mr. James    male  34.50      0      0              330911    7.8292              NaN        Q
# 1            893         1       3                                 Wilkes, Mrs. James (Ellen Needs)  female  47.00      1      0              363272    7.0000              NaN        S
# 2            894         0       2                                        Myles, Mr. Thomas Francis    male  62.00      0      0              240276    9.6875              NaN        Q
# 3            895         0       3                                                 Wirz, Mr. Albert    male  27.00      0      0              315154    8.6625              NaN        S
# ...

# %%
# print(pd.options.display.max_rows) 
# pd.options.display.max_rows = 9999
# df.head(10)
# df.tail(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 408         1300         1       3
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 408                  Riordan, Miss. Johanna Hannah""  female   NaN      0
# 409                        Peacock, Miss. Treasteall  female   3.0      1
# 410                           Naughton, Miss. Hannah  female   NaN      0
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 413                               Spector, Mr. Woolf    male   NaN      0
# ...

# %%
# print(df.head(10)) 
df.head()
# print(df.tail(10))
# df.h()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB
# None

# %%
# df.isnull()
# df.isna().sum()
# df.fillna(value = 0,inplace = True)
c = df.drop(['Cabin','Fare'],axis = 1)
# new_df = df.dropna()
c
# new_df.shape
# df.describe()
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# x = new_df["Fare"].mean()
# x
# x = new_df["Fare"].median()
# x
y = df["Fare"].cumsum()
y
# Out:
# 0          7.8292
# 1         14.8292
# 2         24.5167
# 3         33.1792
# 4         45.4667
# 5         54.6917
# 6         62.3209
# 7         91.3209
# 8         98.5501
# 9        122.7001
# 10       130.5959
# 11       156.5959
# 12       238.8626
# 13       264.8626
# 14       326.0376
# 15       353.7584
# 16       366.1084
# 17       373.3334
# 18       381.2584
# 19       388.4834
# 20       447.8834
# 21       451.0542
# 22       482.7375
# 23       544.1167
# 24       806.4917
# 25       820.9917
# 26       882.9709
# 27       890.1959
# 28       920.6959
# 29       942.3751
# 30       968.3751
# 31       999.8751
# 32      1020.4501
# 33      1043.9001
# 34      1101.6501
# 35      1108.8793
# 36      1116.9293
# 37      1125.5918
# 38      1135.0918
# 39      1191.5876
# 40      1205.0043
# 41      1231.5543
# 42      1239.4043
# 43      1252.4043
# 44      1304.9585
# 45      1312.8835
# 46      1342.5835
# 47      1350.3335
# 48      1426.6252
# 49      1442.5252
# ...

# %%
f = pd.DataFrame({'Animal': ['Falcon', 'Falcon', 'Parrot', 'Parrot'],
                  'Speed': [380., 370., 24., 26.]})
f
# Out:
#    Animal  Speed
# 0  Falcon  380.0
# 1  Falcon  370.0
# 2  Parrot   24.0
# 3  Parrot   26.0

# %%
f.groupby(['Animal']).mean()
# Out:
#         Speed
# Animal
# Falcon  375.0
# Parrot   25.0

# %%
df = pd.DataFrame({'A': [4, 5, 6], 'B': [4, 1, 1]})
print(df)
df.nunique()
# Out:
#    A  B
# 0  4  4
# 1  5  1
# 2  6  1
# A    3
# B    2
# dtype: int64

# %%
df.nunique(axis=1)
# Out:
# 0    1
# 1    2
# 2    2
# dtype: int64

# %%
f = pd.DataFrame({'num_legs': [2, 4, 8, 0],

                   'num_wings': [2, 0, 0, 0],

                   'num_specimen_seen': [10, 2, 1, 8]},

                  index=['falcon', 'dog', 'spider', 'fish'])

f
# Out:
#         num_legs  num_wings  num_specimen_seen
# falcon         2          2                 10
# dog            4          0                  2
# spider         8          0                  1
# fish           0          0                  8

# %%
f['num_legs'].sample(n=3, random_state=42)
# Out:
# dog       4
# fish      0
# falcon    2
# Name: num_legs, dtype: int64

# %%
f.sample(frac=0.5, replace =True ,random_state=1)
# Out:
#       num_legs  num_wings  num_specimen_seen
# dog          4          0                  2
# fish         0          0                  8

# %%
import numpy as np
df = pd.DataFrame({

    'col1': ['A', 'A', 'B', np.nan, 'D', 'C'],

    'col2': [2, 1, 9, 8, 7, 4],

    'col3': [0, 1, 9, 4, 2, 3],

    'col4': ['a', 'B', 'c', 'D', 'e', 'F']

})

df
# Out:
#   col1  col2  col3 col4
# 0    A     2     0    a
# 1    A     1     1    B
# 2    B     9     9    c
# 3  NaN     8     4    D
# 4    D     7     2    e
# 5    C     4     3    F

# %%
df.sort_values(by=['col1'])
# Out:
#   col1  col2  col3 col4
# 0    A     2     0    a
# 1    A     1     1    B
# 2    B     9     9    c
# 5    C     4     3    F
# 4    D     7     2    e
# 3  NaN     8     4    D

# %%
df.sort_values(by='col1', ascending=False, na_position='first')
# Out:
#   col1  col2  col3 col4
# 3  NaN     8     4    D
# 4    D     7     2    e
# 5    C     4     3    F
# 2    B     9     9    c
# 0    A     2     0    a
# 1    A     1     1    B

# %%
df = pd.DataFrame([1, 2, 3, 4, 5], index=[100, 29, 234, 1, 150],columns=['A'])

df.sort_index()
# Out:
#      A
# 1    4
# 29   2
# 100  1
# 150  5
# 234  3

# %%
df = pd.DataFrame(np.array(([1, 2, 3], [4, 5, 6])),

                  index=['mouse', 'rabbit'],

                  columns=['one', 'two', 'three'])

df
# Out:
#         one  two  three
# mouse     1    2      3
# rabbit    4    5      6

# %%
df.filter(items=['one', 'three'])
# Out:
#         one  three
# mouse     1      3
# rabbit    4      6

# %%
df.filter(like='e', axis=1)
# Out:
#         one  three
# mouse     1      3
# rabbit    4      6

# %%
df = pd.DataFrame({"Person":

                   ["John", "Myla", "Lewis", "John", "Myla"],

                   "Age": [24., np.nan, 21., 33, 26],

                   "Single": [False, True, True, True, False]})

df
# Out:
#   Person   Age  Single
# 0   John  24.0   False
# 1   Myla   NaN    True
# 2  Lewis  21.0    True
# 3   John  33.0    True
# 4   Myla  26.0   False

# %%
df.count()
# Out:
# Person    5
# Age       4
# Single    5
# dtype: int64

# %%
df = pd.DataFrame({'A': range(11, 6,-1),

                   'B': range(10, 0, -2),

                   'C': range(10, 5, -1)})

df
# Out:
#     A   B   C
# 0  11  10  10
# 1  10   8   9
# 2   9   6   8
# 3   8   4   7
# 4   7   2   6

# %%
df.query('A > B')
# Out:
#     A   B   C
# 0  11  10  10
# 1  10   8   9
# 2   9   6   8
# 3   8   4   7
# 4   7   2   6

# %%
D = [5, 7, 10, 15,20]
df['D'] = D
df
# Out:
#     A   B   C   D
# 0  11  10  10   5
# 1  10   8   9   7
# 2   9   6   8  10
# 3   8   4   7  15
# 4   7   2   6  20

# %%
df1 = pd.DataFrame({'lkey': ['a', 'b', 'c', 'a'],

                    'value': [1, 2, 3, 5]})

df2 = pd.DataFrame({'rkey': ['a', 'b', 'c', 'a'],

                    'value': [5, 6, 7, 8]})
print(df1)
print(df2)
# Out:
#   lkey  value
# 0    a      1
# 1    b      2
# 2    c      3
# 3    a      5
#   rkey  value
# 0    a      5
# 1    b      6
# 2    c      7
# 3    a      8

# %%
df1.merge(df2,left_on='lkey', right_on='rkey')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-173-fcd616a5f512> in <module>
# ----> 1 df1.merge(df2,left_on='lkey', right_on='rkey',join = "inner")
#
# TypeError: merge() got an unexpected keyword argument 'join'

# %%
ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings',
         'kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
         'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
         'Year': [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
         'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}
df = pd.DataFrame(ipl_data)

df
# grouped = df.groupby('Year')
# print(grouped)
# print(grouped.get_group(2014))
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
g = df.groupby('Year')
print(g.get_group(2014))
# Out:
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 2  Devils     2  2014     863
# 4   Kings     3  2014     741
# 9  Royals     4  2014     701

# %%
one = pd.DataFrame({
         'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
         'subject_id':['sub1','sub2','sub4','sub6','sub5'],
         'Marks_scored':[98,90,87,69,78]},
         index=[1,2,3,4,5])
two = pd.DataFrame({
         'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
         'subject_id':['sub2','sub4','sub3','sub6','sub5'],
         'Marks_scored':[89,80,79,97,88]},
         index=[1,2,3,4,5])
# print (pd.concat([one,two]))
one
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 5  Ayoung       sub5            78

# %%
pd.concat([one,two],axis =0)
# Out:
#      Name subject_id  Marks_scored
# 1    Alex       sub1            98
# 2     Amy       sub2            90
# 3   Allen       sub4            87
# 4   Alice       sub6            69
# 5  Ayoung       sub5            78
# 1   Billy       sub2            89
# 2   Brian       sub4            80
# 3    Bran       sub3            79
# 4   Bryce       sub6            97
# 5   Betty       sub5            88

# %%
pd.concat([one, two], axis=1,ignore_index =False)
# Out:
#      Name subject_id  Marks_scored   Name subject_id  Marks_scored
# 1    Alex       sub1            98  Billy       sub2            89
# 2     Amy       sub2            90  Brian       sub4            80
# 3   Allen       sub4            87   Bran       sub3            79
# 4   Alice       sub6            69  Bryce       sub6            97
# 5  Ayoung       sub5            78  Betty       sub5            88

# %%
f = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3', 'K4', 'K5'],

                   'A': ['A0', 'A1', 'A2', 'A3', 'A4', 'A5']})
f
# Out:
#   key   A
# 0  K0  A0
# 1  K1  A1
# 2  K2  A2
# 3  K3  A3
# 4  K4  A4
# 5  K5  A5

# %%
f2 = pd.DataFrame({'key': ['K0', 'K1', 'K2'],

                      'B': ['B0', 'B1', 'B2']})
f2
# Out:
#   key   B
# 0  K0  B0
# 1  K1  B1
# 2  K2  B2

# %%
f.join(f2,lsuffix = 'k',rsuffix = 't')
# Out:
#   keyk   A keyt    B
# 0   K0  A0   K0   B0
# 1   K1  A1   K1   B1
# 2   K2  A2   K2   B2
# 3   K3  A3  NaN  NaN
# 4   K4  A4  NaN  NaN
# 5   K5  A5  NaN  NaN

# %%
df = pd.DataFrame([[1, 2], [3, 4]], columns=list('AB'), index=['x', 'y'])
df
df2 = pd.DataFrame([[5, 6], [7, 8],[6,8]], columns=list('AB'), index=['x', 'y','z'])
df2.shape
# Out:
# (3, 2)

# %%
df.append(df2)
# Out:
#    A  B
# x  1  2
# y  3  4
# x  5  6
# y  7  8
# z  6  8

# %%
df = pd.DataFrame([[1, 2.12], [3.356, 4.567]])
df
# Out:
#        0      1
# 0  1.000  2.120
# 1  3.356  4.567

# %%
df.applymap(lambda x: x*2)
# Out:
#        0      1
# 0  2.000  4.240
# 1  6.712  9.134

# %%
f = pd.DataFrame([[4, 9]] * 3, columns=['A', 'B'])

# %%
f
# Out:
#    A  B
# 0  4  9
# 1  4  9
# 2  4  9

# %%
import numpy as np

# %%
f = f.apply(np.sqrt)
f
# Out:
#           A         B
# 0  1.414214  1.732051
# 1  1.414214  1.732051
# 2  1.414214  1.732051

# %%
# f.apply(np.sum, axis=0)
f.apply(np.sum, axis=1)
# Out:
# 0    3.146264
# 1    3.146264
# 2    3.146264
# dtype: float64

# %%
s = pd.Series(["dog", "cat", "monkey"])

# %%
s
# Out:
# 0       dog
# 1       cat
# 2    monkey
# dtype: object

# %%
s.rename_axis("animal")
# Out:
# animal
# 0       dog
# 1       cat
# 2    monkey
# dtype: object

# %%
df = pd.DataFrame({"num_legs": [4, 4, 2],

                   "num_arms": [0, 0, 2]},

                  ["dog", "cat", "monkey"])

df
# Out:
#         num_legs  num_arms
# dog            4         0
# cat            4         0
# monkey         2         2

# %%
df = df.rename_axis("h",axis = "rows")

# %%
df
# Out:
# limbs   num_legs  num_arms
# h
# dog            4         0
# cat            4         0
# monkey         2         2

# %%
df = pd.DataFrame(np.arange(12).reshape(3, 4),

                  columns=['A', 'B', 'C', 'D'])

# %%
df
# Out:
#    A  B   C   D
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
df.drop(['B', 'C'], axis=1)
# Out:
#    A   D
# 0  0   3
# 1  4   7
# 2  8  11

# %%
df.drop([0, 1])
# Out:
#      PassengerId  Survived  Pclass  \
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# 6            898         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                      Svensson, Mr. Johan Cervin    male  14.0      0      0
# 6                            Connolly, Miss. Kate  female  30.0      0      0
# ...
